# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("final_data.csv")

# %%
df
# Out:
#            Date        Price
# 0    2002-01-03  3835.000000
# 1    2002-01-04  3835.000000
# 2    2002-01-05  3835.000000
# 3    2002-01-06  3835.000000
# 4    2002-01-07  3835.000000
# ...         ...          ...
# 7455 2022-06-02  4051.000000
# 7456 2022-06-03  4050.000000
# 7457 2022-06-04  4050.333333
# 7458 2022-06-05  4050.666667
# 7459 2022-06-06  4051.000000
#
# [7460 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7460 entries, 0 to 7459
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    7460 non-null   object
#  1   Price   7460 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 116.7+ KB

# %%
df.describe()
# Out:
#              Price
# count  7460.000000
# mean   4025.192599
# std      91.388367
# min    3835.000000
# 25%    3996.500000
# 50%    4042.358333
# 75%    4077.000000
# max    4266.000000

# %%
df.Date= pd.to_datetime(df.Date)
df2 =df.set_index('Date')

# %%
plt.figure(figsize=(10,6))
plt.title('Riel Stock Price')
plt.plot(df2.Price,label='Price')
plt.legend()
plt.show()

# %% [markdown]
# ## ARIMA Model

# %%
data = list(df2["Price"])

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(data)
print("1. ADF : ",result[0])
print("2. P-Value : ", result[1])
print("3. Num Of Lags : ", result[2])
print("4. Num Of Observations Used For ADF Regression:", result[3])
print("5. Critical Values :")
for key, val in result[4].items():
    print("\t",key, ": ", val)
# Out:
# 1. ADF :  -3.26583594811203
# 2. P-Value :  0.016476408530292298
# 3. Num Of Lags :  29
# 4. Num Of Observations Used For ADF Regression: 7430
# 5. Critical Values :
# 	 1% :  -3.4312304253914205
# 	 5% :  -2.861929080831393
# 	 10% :  -2.56697710337307

# %%
from pmdarima.arima.utils import ndiffs
d_value = ndiffs(data,test = "adf")
print("d value:", d_value)
# Out:
# d value: 1

# %%
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima

# %%
x_train= data[:-100]
x_test = data[-100:]
print(len(x_train),len(x_test))
# Out:
# 7360 100

# %%
stepwise_fit = auto_arima(data,trace=True,suppress_warnings=True)
print(stepwise_fit.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=57261.498, Time=2.49 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=57953.261, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=57488.603, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=57362.625, Time=0.38 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=57951.306, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=57263.923, Time=1.09 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=57262.921, Time=1.20 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=57266.109, Time=1.39 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=57263.357, Time=3.54 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=57269.434, Time=0.69 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=57263.191, Time=2.14 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=57262.764, Time=1.48 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=57263.672, Time=2.85 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=57259.673, Time=1.28 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=57262.101, Time=0.57 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=57261.099, Time=0.59 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=57264.288, Time=1.03 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=57261.530, Time=1.12 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=57267.599, Time=0.32 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=57261.362, Time=0.86 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=57260.936, Time=0.70 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=57256.964, Time=2.88 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=57256.992, Time=2.38 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=57257.667, Time=3.30 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=57262.631, Time=1.68 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=57262.612, Time=2.59 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : AIC=57260.910, Time=3.44 sec
#
# Best model:  ARIMA(3,1,3)(0,0,0)[0]
# Total fit time: 40.285 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 7460
# Model:               SARIMAX(3, 1, 3)   Log Likelihood              -28621.482
# Date:                Tue, 18 Apr 2023   AIC                          57256.964
# Time:                        15:32:31   BIC                          57305.384
# Sample:                             0   HQIC                         57273.595
#                                - 7460
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.2435      0.051    -24.567      0.000      -1.343      -1.144
# ar.L2         -0.1567      0.042     -3.770      0.000      -0.238      -0.075
# ar.L3          0.3690      0.021     17.774      0.000       0.328       0.410
# ma.L1          0.9579      0.051     18.704      0.000       0.858       1.058
# ma.L2         -0.2827      0.036     -7.780      0.000      -0.354      -0.211
# ma.L3         -0.5906      0.028    -21.347      0.000      -0.645      -0.536
# sigma2       126.3915      0.620    203.879      0.000     125.176     127.607
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.89   Jarque-Bera (JB):            170201.86
# Prob(Q):                              0.35   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.92   Skew:                             0.25
# Prob(H) (two-sided):                  0.04   Kurtosis:                        26.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
import statsmodels.api as sm
model = sm.tsa.arima.ARIMA(data, order=(2,2,1))

# %%
model = model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 7460
# Model:                 ARIMA(2, 2, 1)   Log Likelihood              -28694.164
# Date:                Tue, 18 Apr 2023   AIC                          57396.329
# Time:                        15:48:20   BIC                          57423.997
# Sample:                             0   HQIC                         57405.833
#                                - 7460
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2741      0.004    -61.075      0.000      -0.283      -0.265
# ar.L2         -0.1137      0.005    -21.214      0.000      -0.124      -0.103
# ma.L1         -1.0000      0.020    -51.160      0.000      -1.038      -0.962
# sigma2       128.4595      2.596     49.475      0.000     123.371     133.548
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.15   Jarque-Bera (JB):            172130.20
# Prob(Q):                              0.28   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.97   Skew:                             0.12
# Prob(H) (two-sided):                  0.41   Kurtosis:                        26.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
start=len(x_train)
end=len(x_train)+len(x_test)-1
pred = model.predict(start=start,end=end)
pred
# Out:
# array([4055.92798641, 4056.04164968, 4056.041644  , 4055.31557294,
#        4052.93335223, 4054.55044513, 4053.24147433, 4052.54232031,
#        4051.42845651, 4050.42826171, 4050.88019745, 4048.74878233,
#        4046.9289503 , 4052.19171997, 4049.84666184, 4046.58981964,
#        4041.86892183, 4033.31440045, 4026.09087244, 4023.83099342,
#        4025.21350134, 4026.66294789, 4028.18597683, 4029.51955691,
#        4033.5153754 , 4035.92133357, 4038.98877773, 4039.69747518,
#        4040.03847666, 4040.03847143, 4040.0384662 , 4040.03846097,
#        4036.40813153, 4039.23617592, 4040.19616564, 4040.92495976,
#        4041.0386234 , 4041.03861815, 4039.58648344, 4039.26556845,
#        4036.13396671, 4035.49214208, 4035.03746149, 4035.0374564 ,
#        4035.03745132, 4034.31138163, 4034.8769863 , 4035.86765115,
#        4034.51995774, 4033.56535089, 4032.40852294, 4031.39832787,
#        4034.04749782, 4034.57932016, 4033.58527167, 4028.88618855,
#        4028.42462853, 4028.63458489, 4029.64476987, 4032.82588722,
#        4033.58250687, 4035.48930582, 4033.6320174 , 4034.58809311,
#        4035.72461286, 4037.39158767, 4039.30058362, 4041.26306444,
#        4041.81130637, 4039.10533953, 4041.37103447, 4044.4697034 ,
#        4048.48378439, 4048.13179993, 4049.71920406, 4049.81277046,
#        4051.49223074, 4051.57111359, 4051.50293906, 4051.16953796,
#        4051.078158  , 4050.31419904, 4050.87980288, 4050.92658333,
#        4050.30208148, 4049.40078264, 4048.38391999, 4047.37915865,
#        4051.49582153, 4052.3528979 , 4053.04058853, 4053.04058305,
#        4053.04057758, 4053.04057211, 4052.31450292, 4050.70191545,
#        4050.99339575, 4050.20044374, 4050.39567349, 4050.57750584])

# %%
s = pd.Series(pred, index =df2.index[-100:])
s
# Out:
# Date
# 2022-02-27    4055.927986
# 2022-02-28    4056.041650
# 2022-03-01    4056.041644
# 2022-03-02    4055.315573
# 2022-03-03    4052.933352
#                  ...
# 2022-06-02    4050.701915
# 2022-06-03    4050.993396
# 2022-06-04    4050.200444
# 2022-06-05    4050.395673
# 2022-06-06    4050.577506
# Length: 100, dtype: float64

# %%
plt.figure(figsize=(10,6), dpi=100)
df2['Price'][-100:].plot(label='Actual Stock Price', legend=True)
s.plot(label='Predicted Price', legend=True,)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from statsmodels.graphics.tsaplots import plot_predict
plot_predict(model, start = len(data)-500, end = len(data)+10, dynamic = False);

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(x_test,pred))
# Out:
# 2.8953142610314884

# %%
from sklearn.metrics import r2_score
r2_score(x_test,pred)
# Out:
# 0.891858652421149

# %% [markdown]
# ## Predicting Future 10 values

# %%
pred_future = model.predict(start=end,end=end+20)
pred_future
# Out:
# array([4050.57750584, 4050.91089592, 4050.93756975, 4050.98052363,
#        4051.00585706, 4051.03416947, 4051.06366804, 4051.09250296,
#        4051.12138495, 4051.15032946, 4051.17925149, 4051.20817258,
#        4051.23709648, 4051.26601971, 4051.29494281, 4051.32386602,
#        4051.35278921, 4051.3817124 , 4051.41063559, 4051.43955878,
#        4051.46848197])

# %%
import datetime
start_date = datetime.datetime(2022,6,6)
dates = [start_date + datetime.timedelta(days=idx) for idx in range(21)]

# %%
pred_future2 = pd.Series(pred_future, index = dates)
pred_future2
# Out:
# 2022-06-06    4050.577506
# 2022-06-07    4050.910896
# 2022-06-08    4050.937570
# 2022-06-09    4050.980524
# 2022-06-10    4051.005857
# 2022-06-11    4051.034169
# 2022-06-12    4051.063668
# 2022-06-13    4051.092503
# 2022-06-14    4051.121385
# 2022-06-15    4051.150329
# 2022-06-16    4051.179251
# 2022-06-17    4051.208173
# 2022-06-18    4051.237096
# 2022-06-19    4051.266020
# 2022-06-20    4051.294943
# 2022-06-21    4051.323866
# 2022-06-22    4051.352789
# 2022-06-23    4051.381712
# 2022-06-24    4051.410636
# 2022-06-25    4051.439559
# 2022-06-26    4051.468482
# dtype: float64

# %%
plt.figure(figsize=(10,6), dpi=100)
df2['Price'][-200:].plot(label='Actual Stock Price', legend=True)
pred_future2.plot(label='Future Predicted Price', legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>
